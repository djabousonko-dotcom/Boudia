# %%
b=4

# %%
print("b")
# Out:
# b

# %%
print(b)
# Out:
# 4

# %%
nom=input("saisir votre nom")
# Out:
# saisir votre nom po

# %%
nom = input("Saisir votre nom: ")

age = input("Votre age: ")

print("Bonjour",nom,"votre agez est de ",age,"ans")
# Out:
# Saisir votre nom:  aicha
# Votre age:  98
# Bonjour aicha votre agez est de  98 ans

# %%
a="hello"
print(a)
# Out:
# hello

# %%
b=3
print(b)
# Out:
# 3

# %%
c=12
print(c)
# Out:
# 12

# %%
k=b+c
print(k)
# Out:
# 15

# %%
a = float(input("saisir la note 1: "))
b = float(input("saisir la note  2: "))

moy = (a+b)/2

print("Moyenne = ",moy)
# Out:
# saisir la note 1:  15
# saisir la note  2:  16.5
# Moyenne =  15.75

# %%
nombre_1 = int(input("Saisir le nombre 1 "))

nombre_2 = int(input("saisir le nombre 2 "))

somme = nombre_1+nombre_2

print("somme = ",somme)
# Out:
# Saisir le nombre 1  25
# saisir le nombre 2  14
# somme =  39

# %%
b= float(input("saisir le nombre 1: "))
f= float(input("saisir le nombre 2: "))
difference= (b-f)
print("difference= ", difference)
# Out:
# saisir le nombre 1:  12
# saisir le nombre 2:  8
# difference=  4.0

# %%
a=int(input("donne un nombre"))
b=int(input("donne un nombre"))
multiplication=a*b
print("multiplication=",multiplication)
# Out:
# donne un nombre 0
# donne un nombre 5
# multiplication= 0

# %%
c=int(input("donne un nombre"))
d=int(input("donne un nombre"))
division=c/d
print("division=",division)
# Out:
# donne un nombre 8
# donne un nombre 9
# division= 0.8888888888888888

# %%
x=int(input("entrer la valeur de x"))
moitie=x/2
print("la moitie=",moitie)
# Out:
# entrer la valeur de x 4
# la moitie= 2.0

# %%
a=int(input("entrer a"))
n=int(input("entrer n"))
puissance=a**n
print("puissance=",puissance)
# Out:
# entrer a 2
# entrer n 4
# puissance= 16
